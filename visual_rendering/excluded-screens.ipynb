# %% [markdown]
# To ensure a correct visualization of the stimuli on the screen, we control that the proportion of the vertical dimension that is occupied by the stimuli (`stimuli_vertical_proportion`) is at least a chosen percentage of the screen (for example 75%).
#
# This notebook is used to find out which device configurations will be excluded from the experiment according to a chosen percentage.
#
# NOTE: the dimensions considered here are always physical, and are calculated in the main script using `DevicePixelRatio`.

# %%
# function to get valid vertical resolutions based on graph size
def get_valid_vertical_resolutions(graph_size):
    if graph_size in [100, 150, 200, 300, 400, 480, 600]:
        valid_vertical_resolutions = [720, 768, 864, 900, 1024, 1050, 1080, 1152, 1200, 1344, 1392, 1400, 1440, 1504, 1536, 1600, 1664, 1800, 1824, 1864, 1920, 1964, 2160, 2234, 2304, 2400, 2520, 2880, 3200, 3328, 3384, 3600, 3840, 4000, 4320, 4468, 5760]
    elif graph_size == 800:
        valid_vertical_resolutions = [864, 900, 1024, 1050, 1080, 1152, 1200, 1344, 1392, 1400, 1440, 1504, 1536, 1600, 1664, 1800, 1824, 1864, 1920, 1964, 2160, 2234, 2304, 2400, 2520, 2880, 3200, 3328, 3384, 3600, 3840, 4000, 4320, 4468, 5760]
    elif graph_size == 1000:
        valid_vertical_resolutions = [1024, 1050, 1080, 1152, 1200, 1344, 1392, 1400, 1440, 1504, 1536, 1600, 1664, 1800, 1824, 1864, 1920, 1964, 2160, 2234, 2304, 2400, 2520, 2880, 3200, 3328, 3384, 3600, 3840, 4000, 4320, 4468, 5760]
    else:
        raise ValueError(f"Invalid graph size, check the 'experiment_parameters.js' file (line 11). Graph size is set to {graph_size}, while allowed graph size values for human experiments are: 100, 150, 200, 300, 400, 480, 600, 800, 1000.")
    
    return valid_vertical_resolutions

# function to calculate the dimension of the single square and the proportion of vertical dimension occupied by the stimuli
def calculate_stimuli_dimensions(graph_size, screen_height):
    # calculating the number of squares to be drawn in the two directions (2 squares are for the diagonal)
    number_of_squares = graph_size + 2

    # calculating the resulting square side dimension (has to be >= 1 pixel)
    square_side_dimension_physical = screen_height // number_of_squares

    # calculating the proportion of vertical dimension that is occupied by the stimuli (has to be more than a % of screen height)
    stimuli_vertical_dimension = number_of_squares * square_side_dimension_physical
    stimuli_vertical_proportion = stimuli_vertical_dimension / screen_height

    # rounding to 2 decimal values
    stimuli_vertical_proportion = round(stimuli_vertical_proportion, 2)

    return stimuli_vertical_proportion

def print_excluded_resolutions(screen_proportion_threshold, graph_sizes = [100, 150, 200, 300, 400, 480, 600, 800, 1000]):
    print(f"Threshold: stimuli vertical proportion: {round(screen_proportion_threshold*100)}, graph sizes: {graph_sizes}")
    print("-----------------------------------")
    # Loop over all N values
    for graph_size in graph_sizes:
        print(f"|||GRAPH SIZE: {graph_size}:")    
        valid_resolutions = get_valid_vertical_resolutions(graph_size)
        # Setting counters for the conditions 
        counter_vertical_proportion = 0
        counter_1 = 0    
        for screen_height in valid_resolutions:
            stimuli_vertical_proportion = calculate_stimuli_dimensions(graph_size, screen_height)
            
            # Check the conditions
            if stimuli_vertical_proportion < screen_proportion_threshold:
                counter_vertical_proportion += 1
                print(f"|||||Excluding screen height {screen_height}: Stimuli vertical proportion is {round(stimuli_vertical_proportion*100)}%")

        # Calculating the proportion of vertical resolutions that are excluded based on each criterion:
        total_resolutions = len(valid_resolutions)
        print(f"|||Graph size {graph_size}: excluding {counter_vertical_proportion} out of {total_resolutions} resolutions based on the stimuli vertical proportion criterion")
        print("|||-----------------------------------")
 
# List of graph sizes
print_excluded_resolutions(0.75) # CHANGE THIS TO TEST DIFFERENT THRESHOLDS
# Out:
# Threshold: stimuli vertical proportion: 75, graph sizes: [100, 150, 200, 300, 400, 480, 600, 800, 1000]
# -----------------------------------
# |||GRAPH SIZE: 100:
# |||Graph size 100: excluding 0 out of 37 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
# |||GRAPH SIZE: 150:
# |||Graph size 150: excluding 0 out of 37 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
# |||GRAPH SIZE: 200:
# |||Graph size 200: excluding 0 out of 37 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
# |||GRAPH SIZE: 300:
# |||||Excluding screen height 864: Stimuli vertical proportion is 70%
# |||||Excluding screen height 900: Stimuli vertical proportion is 67%
# |||Graph size 300: excluding 2 out of 37 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
# |||GRAPH SIZE: 400:
# |||||Excluding screen height 720: Stimuli vertical proportion is 56%
# |||||Excluding screen height 768: Stimuli vertical proportion is 52%
# |||||Excluding screen height 1080: Stimuli vertical proportion is 74%
# |||||Excluding screen height 1152: Stimuli vertical proportion is 70%
# |||||Excluding screen height 1200: Stimuli vertical proportion is 67%
# |||Graph size 400: excluding 5 out of 37 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
# |||GRAPH SIZE: 480:
# |||||Excluding screen height 720: Stimuli vertical proportion is 67%
# |||||Excluding screen height 768: Stimuli vertical proportion is 63%
# |||||Excluding screen height 864: Stimuli vertical proportion is 56%
# |||||Excluding screen height 900: Stimuli vertical proportion is 54%
# |||||Excluding screen height 1344: Stimuli vertical proportion is 72%
# |||||Excluding screen height 1392: Stimuli vertical proportion is 69%
# |||||Excluding screen height 1400: Stimuli vertical proportion is 69%
# |||||Excluding screen height 1440: Stimuli vertical proportion is 67%
# |||Graph size 480: excluding 8 out of 37 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
# |||GRAPH SIZE: 600:
# |||||Excluding screen height 864: Stimuli vertical proportion is 70%
# |||||Excluding screen height 900: Stimuli vertical proportion is 67%
# |||||Excluding screen height 1024: Stimuli vertical proportion is 59%
# |||||Excluding screen height 1050: Stimuli vertical proportion is 57%
# |||||Excluding screen height 1080: Stimuli vertical proportion is 56%
# |||||Excluding screen height 1152: Stimuli vertical proportion is 52%
# |||||Excluding screen height 1200: Stimuli vertical proportion is 50%
# |||||Excluding screen height 1664: Stimuli vertical proportion is 72%
# |||||Excluding screen height 1800: Stimuli vertical proportion is 67%
# |||Graph size 600: excluding 9 out of 37 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
# |||GRAPH SIZE: 800:
# |||||Excluding screen height 1080: Stimuli vertical proportion is 74%
# |||||Excluding screen height 1152: Stimuli vertical proportion is 70%
# |||||Excluding screen height 1200: Stimuli vertical proportion is 67%
# |||||Excluding screen height 1344: Stimuli vertical proportion is 60%
# |||||Excluding screen height 1392: Stimuli vertical proportion is 58%
# |||||Excluding screen height 1400: Stimuli vertical proportion is 57%
# |||||Excluding screen height 1440: Stimuli vertical proportion is 56%
# |||||Excluding screen height 1504: Stimuli vertical proportion is 53%
# |||||Excluding screen height 1536: Stimuli vertical proportion is 52%
# |||||Excluding screen height 1600: Stimuli vertical proportion is 50%
# |||||Excluding screen height 2160: Stimuli vertical proportion is 74%
# |||||Excluding screen height 2234: Stimuli vertical proportion is 72%
# |||||Excluding screen height 2304: Stimuli vertical proportion is 70%
# |||||Excluding screen height 2400: Stimuli vertical proportion is 67%
# |||Graph size 800: excluding 14 out of 35 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
# |||GRAPH SIZE: 1000:
# |||||Excluding screen height 1392: Stimuli vertical proportion is 72%
# |||||Excluding screen height 1400: Stimuli vertical proportion is 72%
# |||||Excluding screen height 1440: Stimuli vertical proportion is 70%
# |||||Excluding screen height 1504: Stimuli vertical proportion is 67%
# |||||Excluding screen height 1536: Stimuli vertical proportion is 65%
# |||||Excluding screen height 1600: Stimuli vertical proportion is 63%
# |||||Excluding screen height 1664: Stimuli vertical proportion is 60%
# |||||Excluding screen height 1800: Stimuli vertical proportion is 56%
# |||||Excluding screen height 1824: Stimuli vertical proportion is 55%
# |||||Excluding screen height 1864: Stimuli vertical proportion is 54%
# |||||Excluding screen height 1920: Stimuli vertical proportion is 52%
# |||||Excluding screen height 1964: Stimuli vertical proportion is 51%
# |||||Excluding screen height 2880: Stimuli vertical proportion is 70%
# |||Graph size 1000: excluding 13 out of 33 resolutions based on the stimuli vertical proportion criterion
# |||-----------------------------------
