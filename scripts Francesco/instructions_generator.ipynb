# %%
import json

grigio = "808080"

data = ["Welcome!", 'In this experiment we will be counting wolves packs.']

text = {"wolf": ("This is a wolf.", "001_Wolf", "400"), 
        "single_track":("When a wolf walks in the snow, it leaves a track.", "Real_tracks", "400"),  
        "line_track":("We will represent this track as a line.", "Single_track", "400"),  
        "pack" : ("This is a pack of wolves.", "003_Pack", "200"),
        "lines" : ("A pack will leave a set of <strong>close tracks</strong> in the snow.", "Tracks", "400"),
        "lines_rep" : ("The tracks can have <strong>many configurations</strong>.", "Tracks", "400", 5),
        "far_line1" : ("The tracks can have <strong>many configurations</strong>.", "Far_track", "400"),
        "far_line" : ("It's rare for a wolf to walk far from its pack.", "Far_track", "400"),
        "second_pack" : ("When we see many tracks far away from those in the pack, there's probably a <strong>second pack</strong>.", "Double_tracks0", "400"),
        "second_pack_col" : ("When we see many tracks far away from those in the pack, there's probably a <strong>second pack</strong>.", "Double_tracks_col0", "400"),
        "Spread_pack" : ("It's also rare for a pack to <strong>spread out</strong> too much.", "Close_packs", "400"),
        "Spread_pack2": ("Wolves of a pack like to keep an eye on each other.", "Close_packs", "400"),
        "Spread_pack3": ("Therefore, spread tracks are again a sign of multiple packs.", "Close_packs", "400", 4),
        "Two_packs0": ("There are only so many wolves in an area, so <strong>more packs</strong> means <strong>smaller packs</strong>.", "Close_packs3", "400"),
        "Two_packs": ("There are only so many wolves in an area, so <strong>more packs</strong> means <strong>smaller packs</strong>.", "Double_tracks_col", "400",4),
        "similar_packs0" : ("Packs have <strong>similar sizes</strong>, otherwise one would drive the other away.", "Double_tracks_col3", "400"),
        "similar_packs" : ("Packs have <strong>similar sizes</strong>, otherwise one would drive the other away.", "Similar_tracks_col", "400",3),
        "overlapping_packs" : ("Sometimes one pack walks over the tracks of another.", "Overlap_tracks", "400"),
        "overlapping_packs_col" : ("Giving the illusion of a single set of tracks.", "Overlap_tracks_col", "400"),
        "three_overlapping_packs" : ("That's true even when we see two sets of tracks.", "Three_overlapping", "400"),
        "three_overlapping_packs_col" : ("As we can have up to <strong>three packs</strong> together.", "Three_overlapping_col", "400"),
        "Three_packs" : ("As we can have up to <strong>three packs</strong> together.", "Triple_tracks_col", "400",5),
        "Trial_explanation1" : ("Your task is to say how many packs there are, by only looking at the white tracks.", "Ex_1", "400"),
        "Trial_explanation2" : ('To do that, press <span style="color: #'+grigio+'">[1]</span>, <span style="color: #'+grigio+'">[2]</span> or <span style="color: #'+grigio+'">[3]</span> on your keyboard.', "Ex_1", "400"),
        "Ex_1": ('For example, here you should clearly press <span style="color: #'+grigio+'">[3]</span>.', "Ex_1", "400",2),
        "Ex_2": ('Here, you should press <span style="color: #'+grigio+'">[2]</span>.', "Ex_2", "400",2),
        "Ex_3a": ('Sometimes it can be hard to tell the number of packs.', "Ex_3a", "400"),
        "Ex_3b": ('Here, the correct answer was <span style="color: #'+grigio+'">[3]</span>.', "Ex_3b", "400"),
        "Ex_30a": ('This is another difficult example.', "Ex_30a", "400"),
        "Ex_30b": ('Here, the correct answer was <span style="color: #'+grigio+'">[2]</span>.', "Ex_30b", "400"),
        "Ex_4a": ('In these cases, just try to make your best guess.', "Ex_4a", "400"),
        "Ex_4b": ('Here, the correct answer was <span style="color: #'+grigio+'">[1]</span>.', "Ex_4b", "400"),
        "Ex_4c": ('But overall, what you now know about packs behaviour should be enough to give an answer, even if it looks difficult.', "Ex_4b", "400"),
        "Ex_5a": ('Like in this case.', "Ex_5a", "400"),
        "Ex_5b": ('Where we have <span style="color: #'+grigio+'">[3]</span> packs.', "Ex_5b", "400"),
        }

for t in text:
    data.append('<img src="img/'+text[t][1]+'.png" height="'+text[t][2]+'"></img>' + '<br>' +  text[t][0])
    if len(text[t])>3:
        for i in range(1,text[t][3]):
                data.append('<img src="img/'+text[t][1]+str(i)+'.png" height="'+text[t][2]+'"></img>' + '<br>' +  text[t][0])
        
data.append('If you have some doubts on the task, <br> go back to the previous instructions using <span style="color: #'+grigio+'">[B]</span>' + ".<p> After this slide, you won't be able to come back.")


for i in range(len(data)):
    comandi = ' <p> <span style="color: #'+grigio+'">Press [Space] to continue.</span>' 
    if (i>0): comandi += ' <br> <span style="color: #'+grigio+'">Press [B] to go back.</span>'
    data[i] = data[i] + comandi


with open('instructions_old.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## Versione vecchia

# %%
text2 = [
        ["Welcome!", "001_Wolf", "0"],
        ['In this experiment we will be counting wolves packs.', "001_Wolf", "0"],
        ["This is a wolf.", "001_Wolf", "400"], 
        ["When a wolf walks in the snow, it leaves a track.", "Real_tracks", "400"],  
        ["We will rapresent this track as a line.", "Single_track", "400"],  
        ["This is a pack of wolves.", "003_Pack", "200"],
        ["A pack will leave a set of <strong>close tracks</strong> in the snow", "Tracks", "400"],
        ["The tracks can have <strong>many configurations</strong>.", "Tracks", "400", 5],
        ["The tracks can have <strong>many configurations</strong>.", "Far_track", "400"],
        ["It's rare for a wolf to walk far from its pack.", "Far_track", "400"],
        ["When we see many tracks far away from those in the pack, there's probably a <strong>second pack</strong>.", "Double_tracks0", "400"],
        ["When we see many tracks far away from those in the pack, there's probably a <strong>second pack</strong>.", "Double_tracks_col0", "400"],
        ["It's also rare for a pack to <strong>spread out</strong> too much.", "Close_packs", "400"],
        ["Wolves of a pack like to keep an eye on each other.", "Close_packs", "400"],
        ["Therefore, spread tracks are again a sign of multiple packs.", "Close_packs", "400", 4],
        ["There are only so many wolves in an area, so <strong>more packs</strong> means <strong>smaller packs</strong>.", "Close_packs3", "400"],
        ["There are only so many wolves in an area, so <strong>more packs</strong> means <strong>smaller packs</strong>.", "Double_tracks_col", "400",4],
        ["Packs have <strong>similar sizes</strong>, otherwise one would drive the other away.", "Double_tracks_col3", "400"],
        ["Packs have <strong>similar sizes</strong>, otherwise one would drive the other away.", "Similar_tracks_col", "400",3],
        ["Sometimes one pack walks over the tracks of another.", "Overlap_tracks", "400"],
        ["Giving the illusion of a single set of tracks.", "Overlap_tracks_col", "400"],
        ["That's true even when we see two sets of tracks.", "Three_overlapping", "400"],
        ["As we can have up to <strong>three packs</strong> together.", "Three_overlapping_col", "400"],
        ["As we can have up to <strong>three packs</strong> together.", "Triple_tracks_col", "400",5],
        ["Your task is to say how many packs there are, by only looking at the white tracks.", "Ex_1", "400"],
        ['To do that, press <span style="color: #'+grigio+'">[1]</span>, <span style="color: #'+grigio+'">[2]</span> or <span style="color: #'+grigio+'">[3]</span> on your keyboard.', "Ex_1", "400"],
        ['For example, here you should clearly press <span style="color: #'+grigio+'">[3]</span>.', "Ex_1", "400",2],
        ['Here, you should press <span style="color: #'+grigio+'">[2]</span>.', "Ex_2", "400",2],
        ['Sometimes it can be hard to tell the number of packs.', "Ex_3a", "400"],
        ['Here, the correct answer was <span style="color: #'+grigio+'">[3]</span>.', "Ex_3b", "400"],
        ['This is another difficult example.', "Ex_30a", "400"],
        ['Here, the correct answer was <span style="color: #'+grigio+'">[2]</span>.', "Ex_30b", "400"],
        ['In these cases, just try to make your best guess.', "Ex_4a", "400"],
        ['Here, the correct answer was <span style="color: #'+grigio+'">[1]</span>.', "Ex_4b", "400"],
        ['But overall, what you now know about packs behaviour should be enough to give an answer, even if it looks difficult.', "Ex_4b", "400"],
        ['Like in this case.', "Ex_5a", "400"],
        ['Where we have <span style="color: #'+grigio+'">[3]</span> packs.', "Ex_5b", "400"],
        ['If you have some doubts on the task, <br> go back to the previous instructions using <span style="color: #'+grigio+'">[B]</span>' + ".<p> After this slide, you won't be able to come back.", "Ex_5b", "0"],
        ]


text3 = []
for t in range(len(text2)):
        text3.append([text2[t][0], text2[t][1], text2[t][2]])
        if len(text2[t])>3:
                for i in range(1,text2[t][3]):
                        text3.append([text2[t][0], text2[t][1] + str(i), text2[t][2]])


for t in range(len(text3)):
        text3[t][1] = "img/" + text3[t][1] + ".png"

for i in range(len(text3)):
    comandi = ' <p> <span style="color: #'+grigio+'">Press [Space] to continue.</span>' 
    if (i>0): comandi += ' <br> <span style="color: #'+grigio+'">Press [B] to go back.</span>'
    text3[i][0] = text3[i][0] + comandi

with open('instructions.json', 'w', encoding='utf-8') as f:
    json.dump(text3, f, ensure_ascii=False, indent=4)
